# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshanavipriya813-tech/c-progamming/blob/main/Unit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
kg=float(input("enter weight in kilograms:"))
pounds=kg*2.20462
print("weight in pounds:",pounds)
# Out:
# enter weight in kilograms:53.3
# weight in pounds: 117.50624599999999
